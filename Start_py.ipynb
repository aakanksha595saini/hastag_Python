# %% [markdown]
# <a href="https://colab.research.google.com/github/aakanksha595saini/hastag_Python/blob/main/Start_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(200//2) # 100
print(200*2) # 400
print(200%2) # 0
print(200**2) # 40000
# Out:
# 100
# 400
# 0
# 40000

# %%
#Write a program which prints all the divisors of a number.
for num in range(1, 10):
    if str(num) == str(num)[::-1]:
        print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# 1.Write a program which prints all the divisors of a number.

num = int(input("enter the number"))
for i in range(1, num+1):
  if num%i == 0:
    print(i)
# Out:
# enter the number20
# 1
# 2
# 4
# 5
# 10
# 20

# %%
#Write a program to check if input number is a prime number.
num=int(input('Enter your number: '))
div_list=[]
for i in range(1,num):
    if num%i==0:
        div_list.append(i)
print(div_list)

nums = 56
factors = [i for i in range(1, nums + 1) if nums % i == 0]
print("Factor", factors)
# Out:
# Enter your number: 90
# [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45]
# Factor [1, 2, 4, 7, 8, 14, 28, 56]

# %%
#2.Write a program to check if input number is a prime number. (a number which cant be divided by any number)
num = int(input("Enter a number: "))
if num > 1:
   for i in range(2,num):
       if (num % i) == 0:
           print(num,"is not a prime number")
           break
   else:
       print(num,"is a prime number")

else:
   print(num,"is not a prime number")
# Out:
# Enter a number: 56
# 56 is not a prime number

# %%
#Armstrong Numbers in a Range - Find all Armstrong numbers (sum of each digit raised to the power of total digits = number) between 100 and 999.
for num in range(100,999):
  sum = 0
  temp = num
  while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10
  if num == sum:
    print(num,"is an Armstrong number")
  #else:
    #print(num,"is not an Armstrong number")
# Out:
# 153 is an Armstrong number
# 370 is an Armstrong number
# 371 is an Armstrong number
# 407 is an Armstrong number

# %%
#.Write a program that prints the numbers from 1 to 100.
#But for multiples of three print “Fizz” instead of the number and
#for the multiples of five print “Buzz”. For numbers which are
#multiples of both three and five print “FizzBuzz”.

for i in range(1,101):
  if (i % 3 == 0):
    print(i,"Fizz");
  if (i % 5 == 0):
    print(i,"Buzz")
  if (i % 3 == 0 & i %5 == 0):
    print(i,"FizzBuzz")
# Out:
# 3 Fizz
# 3 FizzBuzz
# 5 Buzz
# 6 Fizz
# 6 FizzBuzz
# 9 Fizz
# 9 FizzBuzz
# 10 Buzz
# 12 Fizz
# 12 FizzBuzz
# 15 Fizz
# 15 Buzz
# 15 FizzBuzz
# 18 Fizz
# 18 FizzBuzz
# 20 Buzz
# 21 Fizz
# 21 FizzBuzz
# 24 Fizz
# 24 FizzBuzz
# 25 Buzz
# 27 Fizz
# 27 FizzBuzz
# 30 Fizz
# 30 Buzz
# 30 FizzBuzz
# 33 Fizz
# 33 FizzBuzz
# 35 Buzz
# 36 Fizz
# 36 FizzBuzz
# 39 Fizz
# 39 FizzBuzz
# 40 Buzz
# 42 Fizz
# 42 FizzBuzz
# 45 Fizz
# 45 Buzz
# 45 FizzBuzz
# 48 Fizz
# 48 FizzBuzz
# 50 Buzz
# 51 Fizz
# 51 FizzBuzz
# 54 Fizz
# 54 FizzBuzz
# 55 Buzz
# 57 Fizz
# 57 FizzBuzz
# 60 Fizz
# 60 Buzz
# 60 FizzBuzz
# 63 Fizz
# 63 FizzBuzz
# 65 Buzz
# 66 Fizz
# 66 FizzBuzz
# 69 Fizz
# 69 FizzBuzz
# 70 Buzz
# 72 Fizz
# 72 FizzBuzz
# 75 Fizz
# 75 Buzz
# 75 FizzBuzz
# 78 Fizz
# 78 FizzBuzz
# 80 Buzz
# 81 Fizz
# 81 FizzBuzz
# 84 Fizz
# 84 FizzBuzz
# 85 Buzz
# 87 Fizz
# 87 FizzBuzz
# 90 Fizz
# 90 Buzz
# 90 FizzBuzz
# 93 Fizz
# 93 FizzBuzz
# 95 Buzz
# 96 Fizz
# 96 FizzBuzz
# 99 Fizz
# 99 FizzBuzz
# 100 Buzz

# %%
#Write a program to print all the numbers between 1000 and 2000 which are divisible by 7 but are not a multiple of 5.
for i in range(100,201):
 if(i %7 ==0):
  print("divisible by 7 : ",i)
 if(i%5 != 0):
  print("Not multiple of 5 :" ,i)
# Out:
# Not multiple of 5 : 101
# Not multiple of 5 : 102
# Not multiple of 5 : 103
# Not multiple of 5 : 104
# divisible by 7 :  105
# Not multiple of 5 : 106
# Not multiple of 5 : 107
# Not multiple of 5 : 108
# Not multiple of 5 : 109
# Not multiple of 5 : 111
# divisible by 7 :  112
# Not multiple of 5 : 112
# Not multiple of 5 : 113
# Not multiple of 5 : 114
# Not multiple of 5 : 116
# Not multiple of 5 : 117
# Not multiple of 5 : 118
# divisible by 7 :  119
# Not multiple of 5 : 119
# Not multiple of 5 : 121
# Not multiple of 5 : 122
# Not multiple of 5 : 123
# Not multiple of 5 : 124
# divisible by 7 :  126
# Not multiple of 5 : 126
# Not multiple of 5 : 127
# Not multiple of 5 : 128
# Not multiple of 5 : 129
# Not multiple of 5 : 131
# Not multiple of 5 : 132
# divisible by 7 :  133
# Not multiple of 5 : 133
# Not multiple of 5 : 134
# Not multiple of 5 : 136
# Not multiple of 5 : 137
# Not multiple of 5 : 138
# Not multiple of 5 : 139
# divisible by 7 :  140
# ...

# %%
import pandas as pd
file_path = "/kaggle/input/loan-predication/train_u6lujuX_CVtuZ9i (1).csv"

df = pd.read_csv(file_path)
print(df)
#Data Cleaning
#1. Check for Duplicate Rows & remove them if found
#2. Check for NULL values & remove them if found

df[ df.duplicated() ]
# take the last row & duplicate it on purpose

df.loc[614] = df.loc[613]

df.tail()
df[ df.duplicated() ]
df = df.drop_duplicates()

print(df)
df.isna().sum()  # it checks for null values for all columns and give count
df[df.isna().any(axis=1)]   # displays the null values rows
#https://www.kaggle.com/code/metamadyeth/data-cleaning-visualization-engineering
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1074777757.py in <cell line: 0>()
#       2 file_path = "/kaggle/input/loan-predication/train_u6lujuX_CVtuZ9i (1).csv"
#       3
# ----> 4 df = pd.read_csv(file_path)
#       5 print(df)
#       6 #Data Cleaning
#
# ...
